# %%
import tensorflow as tf
import numpy as np
import pandas as pd
from pylab import rcParams
import matplotlib.pyplot as plt
import warnings
from mlxtend.plotting import plot_decision_regions
from matplotlib.colors import ListedColormap
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dropout
from tensorflow.keras.layers import Dense
from tensorflow.keras.callbacks import EarlyStopping
from sklearn.model_selection import train_test_split
from sklearn.datasets import make_circles
import seaborn as sns

# %%
X, y = make_circles(n_samples=100, noise=0.1, random_state=1)

# %%
sns.scatterplot(x=X[:,0],y=X[:,1],hue=y)
# Out:
# <Axes: >

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.20, random_state=2)

# %%
model = Sequential()

model.add(Dense(256, input_dim=2, activation='relu'))
model.add(Dense(1,activation='sigmoid'))
# Out:
# C:\Users\KIIT0001\Downloads\ANACON\envs\ml\Lib\site-packages\keras\src\layers\core\dense.py:92: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)

# %%
model.compile(loss='binary_crossentropy', optimizer='adam', metrics=['accuracy'])

# %%
hist = model.fit(X_train,y_train,validation_data=(X_test,y_test),epochs=3000,verbose=0)

# %%
plt.plot(hist.history['loss'], label='train')
plt.plot(hist.history['val_loss'], label='test')
plt.legend()
plt.show()

# %%
plot_decision_regions(X_test,y_test.ravel(),clf=model,legend=2)
# Out:
# 9600/9600 ━━━━━━━━━━━━━━━━━━━━ 26s 3ms/step
# <Axes: >

# %% [markdown]
# # Early Stopping

# %%
model = Sequential()

model.add(Dense(256, input_dim=2, activation='relu'))
model.add(Dense(1, activation='sigmoid'))
# Out:
# C:\Users\KIIT0001\Downloads\ANACON\envs\ml\Lib\site-packages\keras\src\layers\core\dense.py:92: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)

# %%
model.compile(loss='binary_crossentropy', optimizer='adam', metrics=['accuracy'])

# %%
callback = EarlyStopping(
    monitor="val_loss",
    min_delta=0.00001,
    patience=20,
    verbose=1,
    mode="auto",
    baseline=None,
    restore_best_weights=True
)

# %%
history = model.fit(X_train, y_train, validation_data=(X_test, y_test), epochs=3000, callbacks=callback)
# Out:
# Epoch 1/3000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 140ms/step - accuracy: 0.5875 - loss: 0.6682 - val_accuracy: 0.3500 - val_loss: 0.7233
# Epoch 2/3000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 92ms/step - accuracy: 0.5875 - loss: 0.6673 - val_accuracy: 0.3500 - val_loss: 0.7230
# Epoch 3/3000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 96ms/step - accuracy: 0.5875 - loss: 0.6666 - val_accuracy: 0.3500 - val_loss: 0.7223
# Epoch 4/3000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 90ms/step - accuracy: 0.6000 - loss: 0.6660 - val_accuracy: 0.3500 - val_loss: 0.7208
# Epoch 5/3000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 93ms/step - accuracy: 0.6000 - loss: 0.6652 - val_accuracy: 0.3500 - val_loss: 0.7197
# Epoch 6/3000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 91ms/step - accuracy: 0.5875 - loss: 0.6649 - val_accuracy: 0.3500 - val_loss: 0.7187
# Epoch 7/3000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 108ms/step - accuracy: 0.5750 - loss: 0.6640 - val_accuracy: 0.4000 - val_loss: 0.7176
# Epoch 8/3000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 106ms/step - accuracy: 0.5750 - loss: 0.6632 - val_accuracy: 0.4000 - val_loss: 0.7167
# Epoch 9/3000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 97ms/step - accuracy: 0.5750 - loss: 0.6626 - val_accuracy: 0.4000 - val_loss: 0.7166
# Epoch 10/3000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 86ms/step - accuracy: 0.5875 - loss: 0.6616 - val_accuracy: 0.3500 - val_loss: 0.7165
# Epoch 11/3000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 84ms/step - accuracy: 0.6000 - loss: 0.6611 - val_accuracy: 0.3500 - val_loss: 0.7161
# Epoch 12/3000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 80ms/step - accuracy: 0

# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 90ms/step - accuracy: 0.7250 - loss: 0.6374 - val_accuracy: 0.6000 - val_loss: 0.6906
# Epoch 40/3000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 93ms/step - accuracy: 0.7375 - loss: 0.6360 - val_accuracy: 0.6000 - val_loss: 0.6896
# Epoch 41/3000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 87ms/step - accuracy: 0.7500 - loss: 0.6352 - val_accuracy: 0.6000 - val_loss: 0.6889
# Epoch 42/3000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 79ms/step - accuracy: 0.7500 - loss: 0.6342 - val_accuracy: 0.6000 - val_loss: 0.6882
# Epoch 43/3000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 82ms/step - accuracy: 0.7375 - loss: 0.6331 - val_accuracy: 0.6000 - val_loss: 0.6894
# Epoch 44/3000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 87ms/step - accuracy: 0.7500 - loss: 0.6318 - val_accuracy: 0.6000 - val_loss: 0.6903
# Epoch 45/3000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 73ms/step - accuracy: 0.7375 - loss: 0.6309 - val_accuracy: 0.6000 - val_loss: 0.6923
# Epoch 46/3000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 99ms/step - accuracy: 0.7500 - loss: 0.6295 - val_accuracy: 0.6000 - val_loss: 0.6939
# Epoch 47/3000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 95ms/step - accuracy: 0.7500 - loss: 0.6285 - val_accuracy: 0.6000 - val_loss: 0.6956
# Epoch 48/3000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 79ms/step - accuracy: 0.7375 - loss: 0.6275 - val_accuracy: 0.5500 - val_loss: 0.6970
# Epoch 49/3000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 90ms/step - accuracy: 0.7000 - loss: 0.6269 - val_accuracy: 0.5500 - val_loss: 0.6983
# Epoch 50/3000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 88ms/step - accuracy: 0.7000 - loss: 0.6254 - val_accuracy: 0.6000 - val_loss: 0.6985
# Epoch 51/3000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 86ms/step - accuracy: 0.7125 - loss: 0.6244 - val_accuracy: 0.6000 - val_loss: 0.6994
# Epoch 52/3000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 79ms/step - accuracy: 0.6750 - loss: 0.6236 - val_accuracy: 0.6000 - val_loss: 0.6988
# Epoch 53/3000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 80ms/step - accuracy: 0.6875 - loss: 0.6227 - val_accuracy: 0.6500 - val_loss: 0.6971
# Epoch 54/3000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 75ms/step - accuracy: 0.7000 - loss: 0.6214 - val_accuracy: 0.6500 - val_loss: 0.6975
# Epoch 55/3000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 91ms/step - accuracy: 0.6875 - loss: 0.6203 - val_accuracy: 0.6000 - val_loss: 0.6981
# Epoch 56/3000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 90ms/step - accuracy: 0.7125 - loss: 0.6193 - val_accuracy: 0.6000 - val_loss: 0.6987
# Epoch 57/3000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 81ms/step - accuracy: 0.7250 - loss: 0.6185 - val_accuracy: 0.5500 - val_loss: 0.7000
# Epoch 58/3000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 85ms/step - accuracy: 0.7250 - loss: 0.6170 - val_accuracy: 0.5500 - val_loss: 0.6992
# Epoch 59/3000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 102ms/step - accuracy: 0.7250 - loss: 0.6160 - val_accuracy: 0.6500 - val_loss: 0.6975
# Epoch 60/3000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 110ms/step - accuracy: 0.7125 - loss: 0.6147 - val_accuracy: 0.6000 - val_loss: 0.6972
# Epoch 61/3000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 102ms/step - accuracy: 0.7125 - loss: 0.6138 - val_accuracy: 0.6000 - val_loss: 0.6960
# Epoch 62/3000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 198ms/step - accuracy: 0.7125 - loss: 0.6127 - val_accuracy: 0.6500 - val_loss: 0.6927
# Epoch 62: early stopping
# Restoring model weights from the end of the best epoch: 42.

# %%
plt.plot(history.history['loss'], label='train')
plt.plot(history.history['val_loss'], label='test')
plt.legend()
plt.show()

# %%
plot_decision_regions(X_test, y_test.ravel(), clf = model, legend=2)
plt.show()
# Out:
# 9600/9600 ━━━━━━━━━━━━━━━━━━━━ 27s 3ms/step
